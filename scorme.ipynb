# %%
pip install numpy pandas pikepdf matplotlib

# %%
import os
import re
import logging
import warnings
import pdfplumber
import pandas as pd

from typing import List, Dict, Any

warnings.filterwarnings("ignore")

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s: %(message)s')
logger = logging.getLogger(__name__)

DATE_PATTERN = re.compile(r'(?i)^\d{2}-[A-Za-z]{3}-\d{4}$')

AMOUNT_PATTERN = re.compile(r'^-?\d{1,3}(,\d{3})*(\.\d{1,2})?(Dr|Cr)?$', re.IGNORECASE)

def extract_text_plumber(pdf_path: str) -> str:
   
    full_text = []
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text() or ""
                full_text.append(page_text)
        return "\n".join(full_text)
    except Exception as e:
        logger.error(f"Error opening PDF {pdf_path}: {e}")
        return ""

def parse_statement_lines(text: str, debug: bool = False) -> List[Dict[str, str]]:
    
    results = []
    lines = text.splitlines()
    
    for idx, line in enumerate(lines):
        line = line.strip()
        if not line:
            continue  
        
        if debug:
            print(f"[Line {idx}] {repr(line)}")
        
        tokens = line.split()
        if not tokens:
            continue
        
        if DATE_PATTERN.match(tokens[0]):
            date = tokens[0]
            
            trans_type = ""
            remainder = tokens[1:]
            if remainder and remainder[0] in ("T", "C"):
                trans_type = remainder[0]
                remainder = remainder[1:]
            
            amounts = []
            while remainder and AMOUNT_PATTERN.match(remainder[-1]):
                amounts.insert(0, remainder.pop())
            
            narration = " ".join(remainder)
           
            if len(amounts) == 2:
                transaction_amount = amounts[0]
                balance = amounts[1]
            elif len(amounts) == 1:
                transaction_amount = ""
                balance = amounts[0]
            else:
                transaction_amount = ""
                balance = ""
            
            # Build the record
            record = {
                "Date": date,
                "Trans_Type": trans_type,
                "Narration": narration,
                "Transaction_Amount": transaction_amount,
                "Balance": balance
            }
            results.append(record)
    
    return results

def export_to_excel(records: List[Dict[str, str]], pdf_path: str) -> str:
    
    if not records:
        logger.info("No records to export.")
        return ""
    
    df = pd.DataFrame(records)
    
    output_dir = "extracted_tables"
    os.makedirs(output_dir, exist_ok=True)
    
    base_name = os.path.splitext(os.path.basename(pdf_path))[0]
    excel_path = os.path.join(output_dir, f"{base_name}_parsed.xlsx")
    
    df.to_excel(excel_path, index=False)
    logger.info(f"Parsed data exported to {excel_path}")
    return excel_path

def parse_bank_statement(pdf_path: str, debug: bool = False) -> List[Dict[str, str]]:
    
    text = extract_text_plumber(pdf_path)
    if not text.strip():
        logger.warning("No text extracted from PDF.")
        return []
    
    records = parse_statement_lines(text, debug=debug)
    logger.info(f"Total transactions parsed: {len(records)}")
    
    export_to_excel(records, pdf_path)
    
    return records

if __name__ == "__main__":
    pdf_path = r"C:\Users\DELL\Downloads\test6.pdf"
    parsed_data = parse_bank_statement(pdf_path, debug=False)
    
    if parsed_data:
        # Print first 5 records
        print("Sample Records:")
        for row in parsed_data[:5]:
            print(row)


pdf_path = r"C:\Users\DELL\Downloads\test3.pdf"
parsed_data = parse_bank_statement(pdf_path, debug=True)
# Out:
# 2025-03-26 13:38:07,567 - INFO: Total transactions parsed: 0
# 2025-03-26 13:38:07,567 - INFO: No records to export.
# 2025-03-26 13:38:08,746 - INFO: Total transactions parsed: 70
# 2025-03-26 13:38:08,814 - INFO: Parsed data exported to extracted_tables\test3_parsed.xlsx
# [Line 0] 'BANK NAME : PUNJAB AND SIND BANK 26-06-2023'
# [Line 1] 'BRANCH NAME : JALANDHAR SME 13:15:47'
# [Line 2] 'ADDRESS : 201 INDUSTRIAL AREA'
# [Line 3] 'JALANDHAR'
# [Line 4] 'CITY : JALANDHAR (PUNJAB)'
# [Line 5] 'PIN CODE : 144001'
# [Line 6] 'STATE : Punjab INDIA Page No: 1'
# [Line 7] 'IFSC Code : PSIB0000697'
# [Line 8] 'MICR Code : 144023019 Phone no:'
# [Line 9] '0181-5018936'
# [Line 10] 'REPORT PRINTED BY : MANPRIT KAUR Sol id : 0697'
# [Line 11] '--------------------------------------------------------------------------------'
# [Line 12] '--------------------------------------------------------------------------------'
# [Line 13] '------------------------------'
# [Line 14] 'Account No : 06971300000866 Nomination Registered :'
# [Line 15] 'No'
# [Line 16] 'A/C Name : M/S. KAMAL BRICKS INDUSTRY Nominee Name :'
# [Line 17] 'Address : 560 MOTA SINGH NAGAR'
# [Line 18] 'JALANDHAR'
# [Line 19] 'City : JALANDHAR (PPin Code : 144001'
# [Line 20] 'Tel No. : Sanction Limit :'
# [Line 21] '3000000'
# [Line 22] 'A/C Holder : KAMAL BRICKS INDUSTRY TOD Limit :'
# [Line 23] '0'
# [Line 24] 'Joint Holders: Interest Rate :'
# [Line 25] '13.1'
# [Line 26] 'Open Date : 31-05-2017'
# [Line 27] 'Statement of account for the period of 01-04-2022 to 25-06-2023'
# [Line 28] '01-APR-2022 B/F'
# [Line 29] '30,63,234.66Dr'
# [Line 30] '04-Apr-2022 T BY 06971000010040'
# [Line 31] '25,000.00 30,38,234.66Dr'
# [Line 32] '04-Apr-2022 C By Cash'
# [Line 33] '40,000.00 29,98,234.66Dr'
# [Line 34] '20-Apr-2022 T BY 06971000010040'
# [Line 35] '2,000.00 29,96,234.66Dr'
# [Line 36] '29-Apr-2022 C By Cash'
# [Line 37] '35,000.00 29,61,234.66Dr'
# [Line 38] '30-Apr-2022 T 06971300000866:Int.Coll:01-04-2022 to 30-04-2022'
# [Line 39] '26,168.00 29,87,402.66Dr'
# [Line 40] '30-May-2022 T Inspection Charges Yearly'
# [Line 41] '3,540.00 29,90,942.66Dr'
# [Line 42] '31-May-2022 T 06971300000866:Int.Coll:01-05-2022 to 31-05-2022'
# [Line 43] '26,897.00 30,17,839.66Dr'
# [Line 44] '30-Jun-2022 T 06971300000866:Int.Coll:01-06-2022 to 30-06-2022'
# [Line 45] '26,336.00 30,44,175.66Dr'
# [Line 46] '01-Jul-2022 T Cr-IMPS :P2A/05CREDIT/IMPS/21821/9308141/jaiveer'
# [Line 47] '30,000.00 30,14,175.66Dr'
# [Line 48] '02-Jul-2022 T Cr-IMPS :P2A/TRAMO TECH/'
# [Line 49] '1.00 30,14,174.66Dr'
# [Line 50] '02-Jul-2022 T Cr-IMPS :P2A'
# [Line 51] '25,000.00 29,89,174.66Dr'
# [Line 52] '02-Jul-2022 T Cr-IMPS :P2A'
# [Line 53] '10,000.00 29,79,174.66Dr'
# [Line 54] '04-Jul-2022 T TRANSACTION - LIEN REVERSAL'
# [Line 55] '29.50 29,79,204.16Dr'
# [Line 56] '04-Jul-2022 T TRANSACTION - LIEN REVERSAL'
# [Line 57] '88.50 29,79,292.66Dr'
# [Line 58] '25-Jul-2022 C By Cash'
# [Line 59] '15,000.00 29,64,292.66Dr'
# [Line 60] '26-Jul-2022 C By Cash'
# [Line 61] '2,000.00 29,62,292.66Dr'
# [Line 62] '28-Jul-2022 C TO CASH PAID TO JAIDEEP PADDA 119'
# [Line 63] '20,000.00 29,82,292.66Dr'
# [Line 64] '30-Jul-2022 T Cr-IMPS :P2A'
# [Line 65] '10,000.00 29,72,292.66Dr'
# [Line 66] '30-Jul-2022 T 06971300000866:Int.Coll:01-07-2022 to 31-07-2022'
# [Line 67] '31,582.00 30,03,874.66Dr'
# [Line 68] '31-Aug-2022 T 06971300000866:Int.Coll:01-08-2022 to 31-08-2022'
# [Line 69] '30,347.00 30,34,221.66Dr'
# [Line 70] '21-Sep-2022 C By Cash'
# [Line 71] '35,000.00 29,99,221.66Dr'
# [Line 72] '22-Sep-2022 T TRANSACTION - LIEN REVERSAL'
# [Line 73] '17.70 29,99,239.36Dr'
# [Line 74] '24-Sep-2022 T Ledger Folio Charges'
# [Line 75] '80.00 29,99,319.36Dr'
# [Line 76] '24-Sep-2022 T CGST'
# [Line 77] '14.40 29,99,333.76Dr'
# [Line 78] '27-Sep-2022 C By Cash'
# [Line 79] '15,000.00 29,84,333.76Dr'
# [Line 80] '30-Sep-2022 C By Cash'
# [Line 81] '15,000.00 29,69,333.76Dr'
# [Line 82] 'BANK NAME : PUNJAB AND SIND BANK 26-06-2023'
# [Line 83] 'BRANCH NAME : JALANDHAR SME 13:15:47'
# [Line 84] 'ADDRESS : 201 INDUSTRIAL AREA'
# [Line 85] 'JALANDHAR'
# [Line 86] 'CITY : JALANDHAR (PUNJAB)'
# [Line 87] 'PIN CODE : 144001'
# [Line 88] 'STATE : Punjab INDIA Page No: 2'
# [Line 89] 'IFSC Code : PSIB0000697'
# [Line 90] 'MICR Code : 144023019 Phone no:'
# [Line 91] '0181-5018936'
# [Line 92] 'REPORT PRINTED BY : MANPRIT KAUR Sol id : 0697'
# [Line 93] '--------------------------------------------------------------------------------'
# [Line 94] '--------------------------------------------------------------------------------'
# [Line 95] '------------------------------'
# [Line 96] 'Account No : 06971300000866 Nomination Registered :'
# [Line 97] 'No'
# [Line 98] 'A/C Name : M/S. KAMAL BRICKS INDUSTRY Nominee Name :'
# [Line 99] 'Address : 560 MOTA SINGH NAGAR'
# [Line 100] 'JALANDHAR'
# [Line 101] 'City : JALANDHAR (PPin Code : 144001'
# [Line 102] 'Tel No. : Sanction Limit :'
# [Line 103] '3000000'
# [Line 104] 'A/C Holder : KAMAL BRICKS INDUSTRY TOD Limit :'
# [Line 105] '0'
# [Line 106] 'Joint Holders: Interest Rate :'
# [Line 107] '13.1'
# [Line 108] 'Open Date : 31-05-2017'
# [Line 109] 'Statement of account for the period of 01-04-2022 to 25-06-2023'
# [Line 110] '30-Sep-2022 T 06971300000866:Int.Coll:01-09-2022 to 30-09-2022'
# [Line 111] '29,843.00 29,99,176.76Dr'
# [Line 112] '21-Oct-2022 T BY 06971000010040'
# [Line 113] '30,000.00 29,69,176.76Dr'
# [Line 114] '31-Oct-2022 T 06971300000866:Int.Coll:01-10-2022 to 31-10-2022'
# [Line 115] '31,728.00 30,00,904.76Dr'
# [Line 116] '30-Nov-2022 T 06971300000866:Int.Coll:01-11-2022 to 30-11-2022'
# [Line 117] '30,833.00 30,31,737.76Dr'
# [Line 118] '19-Dec-2022 C By Cash'
# [Line 119] '25,000.00 30,06,737.76Dr'
# [Line 120] '20-Dec-2022 T NEFT/JAIDEEP PADDA/CLBLN22353004318'
# [Line 121] '33,500.00 29,73,237.76Dr'
# [Line 122] '21-Dec-2022 T TRANSACTION - LIEN REVERSAL'
# [Line 123] '5.90 29,73,243.66Dr'
# [Line 124] '23-Dec-2022 C TO CASH SHRIKANT 121'
# [Line 125] '20,000.00 29,93,243.66Dr'
# [Line 126] '23-Dec-2022 T Cr-IMPS :P2Ab/RZPX PVT L/'
# [Line 127] '15,000.00 29,78,243.66Dr'
# [Line 128] '24-Dec-2022 T Ledger Folio Charges'
# [Line 129] '80.00 29,78,323.66Dr'
# [Line 130] '24-Dec-2022 T CGST'
# [Line 131] '14.40 29,78,338.06Dr'
# [Line 132] '27-Dec-2022 C TO CASH SHRIKANT 122'
# [Line 133] '15,000.00 29,93,338.06Dr'
# [Line 134] '31-Dec-2022 T 06971300000866:Int.Coll:01-12-2022 to 31-12-2022'
# [Line 135] '32,718.00 30,26,056.06Dr'
# [Line 136] '19-Jan-2023 T Cr-IMPS :P2Ab/Razorpay /'
# [Line 137] '25,000.00 30,01,056.06Dr'
# [Line 138] '19-Jan-2023 T Cr-IMPS :P2Ab/Razorpay /'
# [Line 139] '5,000.00 29,96,056.06Dr'
# [Line 140] '31-Jan-2023 T 06971300000866:Int.Coll:01-01-2023 to 31-01-2023'
# [Line 141] '33,255.00 30,29,311.06Dr'
# [Line 142] '28-Feb-2023 T 06971300000866:Int.Coll:01-02-2023 to 28-02-2023'
# [Line 143] '34,947.00 30,64,258.06Dr'
# [Line 144] '20-Mar-2023 C By Cash'
# [Line 145] '25,000.00 30,39,258.06Dr'
# [Line 146] '20-Mar-2023 T EXPERT TUBEWELL'
# [Line 147] '35,000.00 30,04,258.06Dr'
# [Line 148] '22-Mar-2023 T UPI/CR/308125203694/GAGANDEEP SINGH/CLBL/013205016'
# [Line 149] '20,000.00 29,84,258.06Dr'
# [Line 150] '24-Mar-2023 T FROM 13/866'
# [Line 151] '5,17,400.00 24,66,858.06Dr'
# [Line 152] '24-Mar-2023 T TO 13/665 123'
# [Line 153] '2,41,000.00 27,07,858.06Dr'
# [Line 154] '24-Mar-2023 C TO CASH 125'
# [Line 155] '2,70,000.00 29,77,858.06Dr'
# [Line 156] '25-Mar-2023 T Ledger Folio Charges'
# [Line 157] '80.00 29,77,938.06Dr'
# [Line 158] '25-Mar-2023 T CGST'
# [Line 159] '14.40 29,77,952.46Dr'
# [Line 160] '27-Mar-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 161] '5.90 29,77,958.36Dr'
# [Line 162] '27-Mar-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 163] '3,481.00 29,81,439.36Dr'
# [Line 164] 'BANK NAME : PUNJAB AND SIND BANK 26-06-2023'
# [Line 165] 'BRANCH NAME : JALANDHAR SME 13:15:47'
# [Line 166] 'ADDRESS : 201 INDUSTRIAL AREA'
# [Line 167] 'JALANDHAR'
# [Line 168] 'CITY : JALANDHAR (PUNJAB)'
# [Line 169] 'PIN CODE : 144001'
# [Line 170] 'STATE : Punjab INDIA Page No: 3'
# [Line 171] 'IFSC Code : PSIB0000697'
# [Line 172] 'MICR Code : 144023019 Phone no:'
# [Line 173] '0181-5018936'
# [Line 174] 'REPORT PRINTED BY : MANPRIT KAUR Sol id : 0697'
# [Line 175] '--------------------------------------------------------------------------------'
# [Line 176] '--------------------------------------------------------------------------------'
# [Line 177] '------------------------------'
# [Line 178] 'Account No : 06971300000866 Nomination Registered :'
# [Line 179] 'No'
# [Line 180] 'A/C Name : M/S. KAMAL BRICKS INDUSTRY Nominee Name :'
# [Line 181] 'Address : 560 MOTA SINGH NAGAR'
# [Line 182] 'JALANDHAR'
# [Line 183] 'City : JALANDHAR (PPin Code : 144001'
# [Line 184] 'Tel No. : Sanction Limit :'
# [Line 185] '3000000'
# [Line 186] 'A/C Holder : KAMAL BRICKS INDUSTRY TOD Limit :'
# [Line 187] '0'
# [Line 188] 'Joint Holders: Interest Rate :'
# [Line 189] '13.1'
# [Line 190] 'Open Date : 31-05-2017'
# [Line 191] 'Statement of account for the period of 01-04-2022 to 25-06-2023'
# [Line 192] '27-Mar-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 193] '17,700.00 29,99,139.36Dr'
# [Line 194] '31-Mar-2023 T Cr-IMPS :P2A/05CREDIT/IMPS/30901/5852595/Remittanc'
# [Line 195] '25,000.00 29,74,139.36Dr'
# [Line 196] '31-Mar-2023 T Cr-IMPS :P2A/05CREDIT/IMPS/30901/5855413/Remittanc'
# [Line 197] '10,000.00 29,64,139.36Dr'
# [Line 198] '31-Mar-2023 T 06971300000866:Int.Coll:01-03-2023 to 31-03-2023'
# [Line 199] '38,959.00 30,03,098.36Dr'
# [Line 200] '29-Apr-2023 T 06971300000866:Int.Coll:01-04-2023 to 30-04-2023'
# [Line 201] '37,274.00 30,40,372.36Dr'
# [Line 202] '31-May-2023 T 06971300000866:Int.Coll:01-05-2023 to 31-05-2023'
# [Line 203] '39,026.00 30,79,398.36Dr'
# [Line 204] '22-Jun-2023 T JAY PEE AND SONS'
# [Line 205] '1,00,000.00 29,79,398.36Dr'
# [Line 206] '22-Jun-2023 T Cr-IMPS :P2A/MSEWA SOFT/'
# [Line 207] '15,000.00 29,64,398.36Dr'
# [Line 208] '22-Jun-2023 T UPI/CR/317342835941/GAGANDEEP SINGH MARVAY/KKBK/32'
# [Line 209] '10,000.00 29,54,398.36Dr'
# [Line 210] '23-Jun-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 211] '318.60 29,54,716.96Dr'
# [Line 212] '23-Jun-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 213] '318.60 29,55,035.56Dr'
# [Line 214] '23-Jun-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 215] '3,540.00 29,58,575.56Dr'
# [Line 216] '23-Jun-2023 C By Cash'
# [Line 217] '1,00,000.00 28,58,575.56Dr'
# [Line 218] '23-Jun-2023 T TRF/ TO JAYPEE AND SONS 126'
# [Line 219] '1,00,000.00 29,58,575.56Dr'
# [Line 220] '24-Jun-2023 T Ledger Folio Charges'
# [Line 221] '80.00 29,58,655.56Dr'
# [Line 222] '24-Jun-2023 T CGST'
# [Line 223] '14.40 29,58,669.96Dr'
# [Line 224] '--------------------------------------------------------------------------------'
# [Line 225] '--------------------------------------------------------------------------------'
# [Line 226] '------------------------------'
# [Line 227] 'Grand Total:'
# [Line 228] '11,45,336.30 12,49,901.00 29,58,669.96Dr'
# [Line 229] '--------------------------------------------------------------------------------'
# [Line 230] '--------------------------------------------------------------------------------'
# [Line 231] '------------------------------'
# [Line 232] 'Please examine your statement immediately on receipt'
# [Line 233] 'If no error is reported in the printed statement'
# [Line 234] 'within 15 days, the account will be considered correct'
# [Line 235] 'Manager _____________'
# [Line 236] 'BANK NAME : PUNJAB AND SIND BANK 26-06-2023'
# [Line 237] 'BRANCH NAME : JALANDHAR SME 13:15:47'
# [Line 238] 'ADDRESS : 201 INDUSTRIAL AREA'
# [Line 239] 'JALANDHAR'
# [Line 240] 'CITY : JALANDHAR (PUNJAB)'
# [Line 241] 'PIN CODE : 144001'
# [Line 242] 'STATE : Punjab INDIA Page No: 4'
# [Line 243] 'IFSC Code : PSIB0000697'
# [Line 244] 'MICR Code : 144023019 Phone no:'
# [Line 245] '0181-5018936'
# [Line 246] 'REPORT PRINTED BY : MANPRIT KAUR Sol id : 0697'
# [Line 247] '--------------------------------------------------------------------------------'
# [Line 248] '--------------------------------------------------------------------------------'
# [Line 249] '------------------------------'
# [Line 250] 'Account No : 06971300000866 Nomination Registered :'
# [Line 251] 'No'
# [Line 252] 'A/C Name : M/S. KAMAL BRICKS INDUSTRY Nominee Name :'
# [Line 253] 'Address : 560 MOTA SINGH NAGAR'
# [Line 254] 'JALANDHAR'
# [Line 255] 'City : JALANDHAR (PPin Code : 144001'
# [Line 256] 'Tel No. : Sanction Limit :'
# [Line 257] '3000000'
# [Line 258] 'A/C Holder : KAMAL BRICKS INDUSTRY TOD Limit :'
# [Line 259] '0'
# [Line 260] 'Joint Holders: Interest Rate :'
# [Line 261] '13.1'
# [Line 262] 'Open Date : 31-05-2017'
# [Line 263] 'Statement of account for the period of 01-04-2022 to 25-06-2023'
# [Line 264] 'REPORT!MAILID#'
# [Line 265] 'NOTE:'
# [Line 266] '1) Maximum interest rate is displayed for account with multiple Sanction Limits'
# [Line 267] '2) Sanction Limit and Interest Rate is as on Calendar date'
# [Line 268] '3) For further clarification regarding Sanction Limit and Interest Rate please'
# [Line 269] 'contact home branch'
# [Line 270] 'Note:DICGC insures principal & interest of eligible depositors,upto a maximum'
# [Line 271] 'admissible amount of Rs 5 lakh'
# [Line 272] 'subject to changes from time to time**T&C of DICGC shall apply.'
# [Line 273] '****END OF STATEMENT****'

# %%
pdf_path = r"C:\Users\DELL\Downloads\test3.pdf"
parsed_data = parse_bank_statement(pdf_path, debug=True)
# Out:
# 2025-03-26 13:36:15,217 - INFO: Total transactions parsed: 70
# 2025-03-26 13:36:15,282 - INFO: Parsed data exported to extracted_tables\test3_parsed.xlsx
# [Line 0] 'BANK NAME : PUNJAB AND SIND BANK 26-06-2023'
# [Line 1] 'BRANCH NAME : JALANDHAR SME 13:15:47'
# [Line 2] 'ADDRESS : 201 INDUSTRIAL AREA'
# [Line 3] 'JALANDHAR'
# [Line 4] 'CITY : JALANDHAR (PUNJAB)'
# [Line 5] 'PIN CODE : 144001'
# [Line 6] 'STATE : Punjab INDIA Page No: 1'
# [Line 7] 'IFSC Code : PSIB0000697'
# [Line 8] 'MICR Code : 144023019 Phone no:'
# [Line 9] '0181-5018936'
# [Line 10] 'REPORT PRINTED BY : MANPRIT KAUR Sol id : 0697'
# [Line 11] '--------------------------------------------------------------------------------'
# [Line 12] '--------------------------------------------------------------------------------'
# [Line 13] '------------------------------'
# [Line 14] 'Account No : 06971300000866 Nomination Registered :'
# [Line 15] 'No'
# [Line 16] 'A/C Name : M/S. KAMAL BRICKS INDUSTRY Nominee Name :'
# [Line 17] 'Address : 560 MOTA SINGH NAGAR'
# [Line 18] 'JALANDHAR'
# [Line 19] 'City : JALANDHAR (PPin Code : 144001'
# [Line 20] 'Tel No. : Sanction Limit :'
# [Line 21] '3000000'
# [Line 22] 'A/C Holder : KAMAL BRICKS INDUSTRY TOD Limit :'
# [Line 23] '0'
# [Line 24] 'Joint Holders: Interest Rate :'
# [Line 25] '13.1'
# [Line 26] 'Open Date : 31-05-2017'
# [Line 27] 'Statement of account for the period of 01-04-2022 to 25-06-2023'
# [Line 28] '01-APR-2022 B/F'
# [Line 29] '30,63,234.66Dr'
# [Line 30] '04-Apr-2022 T BY 06971000010040'
# [Line 31] '25,000.00 30,38,234.66Dr'
# [Line 32] '04-Apr-2022 C By Cash'
# [Line 33] '40,000.00 29,98,234.66Dr'
# [Line 34] '20-Apr-2022 T BY 06971000010040'
# [Line 35] '2,000.00 29,96,234.66Dr'
# [Line 36] '29-Apr-2022 C By Cash'
# [Line 37] '35,000.00 29,61,234.66Dr'
# [Line 38] '30-Apr-2022 T 06971300000866:Int.Coll:01-04-2022 to 30-04-2022'
# [Line 39] '26,168.00 29,87,402.66Dr'
# [Line 40] '30-May-2022 T Inspection Charges Yearly'
# [Line 41] '3,540.00 29,90,942.66Dr'
# [Line 42] '31-May-2022 T 06971300000866:Int.Coll:01-05-2022 to 31-05-2022'
# [Line 43] '26,897.00 30,17,839.66Dr'
# [Line 44] '30-Jun-2022 T 06971300000866:Int.Coll:01-06-2022 to 30-06-2022'
# [Line 45] '26,336.00 30,44,175.66Dr'
# [Line 46] '01-Jul-2022 T Cr-IMPS :P2A/05CREDIT/IMPS/21821/9308141/jaiveer'
# [Line 47] '30,000.00 30,14,175.66Dr'
# [Line 48] '02-Jul-2022 T Cr-IMPS :P2A/TRAMO TECH/'
# [Line 49] '1.00 30,14,174.66Dr'
# [Line 50] '02-Jul-2022 T Cr-IMPS :P2A'
# [Line 51] '25,000.00 29,89,174.66Dr'
# [Line 52] '02-Jul-2022 T Cr-IMPS :P2A'
# [Line 53] '10,000.00 29,79,174.66Dr'
# [Line 54] '04-Jul-2022 T TRANSACTION - LIEN REVERSAL'
# [Line 55] '29.50 29,79,204.16Dr'
# [Line 56] '04-Jul-2022 T TRANSACTION - LIEN REVERSAL'
# [Line 57] '88.50 29,79,292.66Dr'
# [Line 58] '25-Jul-2022 C By Cash'
# [Line 59] '15,000.00 29,64,292.66Dr'
# [Line 60] '26-Jul-2022 C By Cash'
# [Line 61] '2,000.00 29,62,292.66Dr'
# [Line 62] '28-Jul-2022 C TO CASH PAID TO JAIDEEP PADDA 119'
# [Line 63] '20,000.00 29,82,292.66Dr'
# [Line 64] '30-Jul-2022 T Cr-IMPS :P2A'
# [Line 65] '10,000.00 29,72,292.66Dr'
# [Line 66] '30-Jul-2022 T 06971300000866:Int.Coll:01-07-2022 to 31-07-2022'
# [Line 67] '31,582.00 30,03,874.66Dr'
# [Line 68] '31-Aug-2022 T 06971300000866:Int.Coll:01-08-2022 to 31-08-2022'
# [Line 69] '30,347.00 30,34,221.66Dr'
# [Line 70] '21-Sep-2022 C By Cash'
# [Line 71] '35,000.00 29,99,221.66Dr'
# [Line 72] '22-Sep-2022 T TRANSACTION - LIEN REVERSAL'
# [Line 73] '17.70 29,99,239.36Dr'
# [Line 74] '24-Sep-2022 T Ledger Folio Charges'
# [Line 75] '80.00 29,99,319.36Dr'
# [Line 76] '24-Sep-2022 T CGST'
# [Line 77] '14.40 29,99,333.76Dr'
# [Line 78] '27-Sep-2022 C By Cash'
# [Line 79] '15,000.00 29,84,333.76Dr'
# [Line 80] '30-Sep-2022 C By Cash'
# [Line 81] '15,000.00 29,69,333.76Dr'
# [Line 82] 'BANK NAME : PUNJAB AND SIND BANK 26-06-2023'
# [Line 83] 'BRANCH NAME : JALANDHAR SME 13:15:47'
# [Line 84] 'ADDRESS : 201 INDUSTRIAL AREA'
# [Line 85] 'JALANDHAR'
# [Line 86] 'CITY : JALANDHAR (PUNJAB)'
# [Line 87] 'PIN CODE : 144001'
# [Line 88] 'STATE : Punjab INDIA Page No: 2'
# [Line 89] 'IFSC Code : PSIB0000697'
# [Line 90] 'MICR Code : 144023019 Phone no:'
# [Line 91] '0181-5018936'
# [Line 92] 'REPORT PRINTED BY : MANPRIT KAUR Sol id : 0697'
# [Line 93] '--------------------------------------------------------------------------------'
# [Line 94] '--------------------------------------------------------------------------------'
# [Line 95] '------------------------------'
# [Line 96] 'Account No : 06971300000866 Nomination Registered :'
# [Line 97] 'No'
# [Line 98] 'A/C Name : M/S. KAMAL BRICKS INDUSTRY Nominee Name :'
# [Line 99] 'Address : 560 MOTA SINGH NAGAR'
# [Line 100] 'JALANDHAR'
# [Line 101] 'City : JALANDHAR (PPin Code : 144001'
# [Line 102] 'Tel No. : Sanction Limit :'
# [Line 103] '3000000'
# [Line 104] 'A/C Holder : KAMAL BRICKS INDUSTRY TOD Limit :'
# [Line 105] '0'
# [Line 106] 'Joint Holders: Interest Rate :'
# [Line 107] '13.1'
# [Line 108] 'Open Date : 31-05-2017'
# [Line 109] 'Statement of account for the period of 01-04-2022 to 25-06-2023'
# [Line 110] '30-Sep-2022 T 06971300000866:Int.Coll:01-09-2022 to 30-09-2022'
# [Line 111] '29,843.00 29,99,176.76Dr'
# [Line 112] '21-Oct-2022 T BY 06971000010040'
# [Line 113] '30,000.00 29,69,176.76Dr'
# [Line 114] '31-Oct-2022 T 06971300000866:Int.Coll:01-10-2022 to 31-10-2022'
# [Line 115] '31,728.00 30,00,904.76Dr'
# [Line 116] '30-Nov-2022 T 06971300000866:Int.Coll:01-11-2022 to 30-11-2022'
# [Line 117] '30,833.00 30,31,737.76Dr'
# [Line 118] '19-Dec-2022 C By Cash'
# [Line 119] '25,000.00 30,06,737.76Dr'
# [Line 120] '20-Dec-2022 T NEFT/JAIDEEP PADDA/CLBLN22353004318'
# [Line 121] '33,500.00 29,73,237.76Dr'
# [Line 122] '21-Dec-2022 T TRANSACTION - LIEN REVERSAL'
# [Line 123] '5.90 29,73,243.66Dr'
# [Line 124] '23-Dec-2022 C TO CASH SHRIKANT 121'
# [Line 125] '20,000.00 29,93,243.66Dr'
# [Line 126] '23-Dec-2022 T Cr-IMPS :P2Ab/RZPX PVT L/'
# [Line 127] '15,000.00 29,78,243.66Dr'
# [Line 128] '24-Dec-2022 T Ledger Folio Charges'
# [Line 129] '80.00 29,78,323.66Dr'
# [Line 130] '24-Dec-2022 T CGST'
# [Line 131] '14.40 29,78,338.06Dr'
# [Line 132] '27-Dec-2022 C TO CASH SHRIKANT 122'
# [Line 133] '15,000.00 29,93,338.06Dr'
# [Line 134] '31-Dec-2022 T 06971300000866:Int.Coll:01-12-2022 to 31-12-2022'
# [Line 135] '32,718.00 30,26,056.06Dr'
# [Line 136] '19-Jan-2023 T Cr-IMPS :P2Ab/Razorpay /'
# [Line 137] '25,000.00 30,01,056.06Dr'
# [Line 138] '19-Jan-2023 T Cr-IMPS :P2Ab/Razorpay /'
# [Line 139] '5,000.00 29,96,056.06Dr'
# [Line 140] '31-Jan-2023 T 06971300000866:Int.Coll:01-01-2023 to 31-01-2023'
# [Line 141] '33,255.00 30,29,311.06Dr'
# [Line 142] '28-Feb-2023 T 06971300000866:Int.Coll:01-02-2023 to 28-02-2023'
# [Line 143] '34,947.00 30,64,258.06Dr'
# [Line 144] '20-Mar-2023 C By Cash'
# [Line 145] '25,000.00 30,39,258.06Dr'
# [Line 146] '20-Mar-2023 T EXPERT TUBEWELL'
# [Line 147] '35,000.00 30,04,258.06Dr'
# [Line 148] '22-Mar-2023 T UPI/CR/308125203694/GAGANDEEP SINGH/CLBL/013205016'
# [Line 149] '20,000.00 29,84,258.06Dr'
# [Line 150] '24-Mar-2023 T FROM 13/866'
# [Line 151] '5,17,400.00 24,66,858.06Dr'
# [Line 152] '24-Mar-2023 T TO 13/665 123'
# [Line 153] '2,41,000.00 27,07,858.06Dr'
# [Line 154] '24-Mar-2023 C TO CASH 125'
# [Line 155] '2,70,000.00 29,77,858.06Dr'
# [Line 156] '25-Mar-2023 T Ledger Folio Charges'
# [Line 157] '80.00 29,77,938.06Dr'
# [Line 158] '25-Mar-2023 T CGST'
# [Line 159] '14.40 29,77,952.46Dr'
# [Line 160] '27-Mar-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 161] '5.90 29,77,958.36Dr'
# [Line 162] '27-Mar-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 163] '3,481.00 29,81,439.36Dr'
# [Line 164] 'BANK NAME : PUNJAB AND SIND BANK 26-06-2023'
# [Line 165] 'BRANCH NAME : JALANDHAR SME 13:15:47'
# [Line 166] 'ADDRESS : 201 INDUSTRIAL AREA'
# [Line 167] 'JALANDHAR'
# [Line 168] 'CITY : JALANDHAR (PUNJAB)'
# [Line 169] 'PIN CODE : 144001'
# [Line 170] 'STATE : Punjab INDIA Page No: 3'
# [Line 171] 'IFSC Code : PSIB0000697'
# [Line 172] 'MICR Code : 144023019 Phone no:'
# [Line 173] '0181-5018936'
# [Line 174] 'REPORT PRINTED BY : MANPRIT KAUR Sol id : 0697'
# [Line 175] '--------------------------------------------------------------------------------'
# [Line 176] '--------------------------------------------------------------------------------'
# [Line 177] '------------------------------'
# [Line 178] 'Account No : 06971300000866 Nomination Registered :'
# [Line 179] 'No'
# [Line 180] 'A/C Name : M/S. KAMAL BRICKS INDUSTRY Nominee Name :'
# [Line 181] 'Address : 560 MOTA SINGH NAGAR'
# [Line 182] 'JALANDHAR'
# [Line 183] 'City : JALANDHAR (PPin Code : 144001'
# [Line 184] 'Tel No. : Sanction Limit :'
# [Line 185] '3000000'
# [Line 186] 'A/C Holder : KAMAL BRICKS INDUSTRY TOD Limit :'
# [Line 187] '0'
# [Line 188] 'Joint Holders: Interest Rate :'
# [Line 189] '13.1'
# [Line 190] 'Open Date : 31-05-2017'
# [Line 191] 'Statement of account for the period of 01-04-2022 to 25-06-2023'
# [Line 192] '27-Mar-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 193] '17,700.00 29,99,139.36Dr'
# [Line 194] '31-Mar-2023 T Cr-IMPS :P2A/05CREDIT/IMPS/30901/5852595/Remittanc'
# [Line 195] '25,000.00 29,74,139.36Dr'
# [Line 196] '31-Mar-2023 T Cr-IMPS :P2A/05CREDIT/IMPS/30901/5855413/Remittanc'
# [Line 197] '10,000.00 29,64,139.36Dr'
# [Line 198] '31-Mar-2023 T 06971300000866:Int.Coll:01-03-2023 to 31-03-2023'
# [Line 199] '38,959.00 30,03,098.36Dr'
# [Line 200] '29-Apr-2023 T 06971300000866:Int.Coll:01-04-2023 to 30-04-2023'
# [Line 201] '37,274.00 30,40,372.36Dr'
# [Line 202] '31-May-2023 T 06971300000866:Int.Coll:01-05-2023 to 31-05-2023'
# [Line 203] '39,026.00 30,79,398.36Dr'
# [Line 204] '22-Jun-2023 T JAY PEE AND SONS'
# [Line 205] '1,00,000.00 29,79,398.36Dr'
# [Line 206] '22-Jun-2023 T Cr-IMPS :P2A/MSEWA SOFT/'
# [Line 207] '15,000.00 29,64,398.36Dr'
# [Line 208] '22-Jun-2023 T UPI/CR/317342835941/GAGANDEEP SINGH MARVAY/KKBK/32'
# [Line 209] '10,000.00 29,54,398.36Dr'
# [Line 210] '23-Jun-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 211] '318.60 29,54,716.96Dr'
# [Line 212] '23-Jun-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 213] '318.60 29,55,035.56Dr'
# [Line 214] '23-Jun-2023 T TRANSACTION - LIEN REVERSAL'
# [Line 215] '3,540.00 29,58,575.56Dr'
# [Line 216] '23-Jun-2023 C By Cash'
# [Line 217] '1,00,000.00 28,58,575.56Dr'
# [Line 218] '23-Jun-2023 T TRF/ TO JAYPEE AND SONS 126'
# [Line 219] '1,00,000.00 29,58,575.56Dr'
# [Line 220] '24-Jun-2023 T Ledger Folio Charges'
# [Line 221] '80.00 29,58,655.56Dr'
# [Line 222] '24-Jun-2023 T CGST'
# [Line 223] '14.40 29,58,669.96Dr'
# [Line 224] '--------------------------------------------------------------------------------'
# [Line 225] '--------------------------------------------------------------------------------'
# [Line 226] '------------------------------'
# [Line 227] 'Grand Total:'
# [Line 228] '11,45,336.30 12,49,901.00 29,58,669.96Dr'
# [Line 229] '--------------------------------------------------------------------------------'
# [Line 230] '--------------------------------------------------------------------------------'
# [Line 231] '------------------------------'
# [Line 232] 'Please examine your statement immediately on receipt'
# [Line 233] 'If no error is reported in the printed statement'
# [Line 234] 'within 15 days, the account will be considered correct'
# [Line 235] 'Manager _____________'
# [Line 236] 'BANK NAME : PUNJAB AND SIND BANK 26-06-2023'
# [Line 237] 'BRANCH NAME : JALANDHAR SME 13:15:47'
# [Line 238] 'ADDRESS : 201 INDUSTRIAL AREA'
# [Line 239] 'JALANDHAR'
# [Line 240] 'CITY : JALANDHAR (PUNJAB)'
# [Line 241] 'PIN CODE : 144001'
# [Line 242] 'STATE : Punjab INDIA Page No: 4'
# [Line 243] 'IFSC Code : PSIB0000697'
# [Line 244] 'MICR Code : 144023019 Phone no:'
# [Line 245] '0181-5018936'
# [Line 246] 'REPORT PRINTED BY : MANPRIT KAUR Sol id : 0697'
# [Line 247] '--------------------------------------------------------------------------------'
# [Line 248] '--------------------------------------------------------------------------------'
# [Line 249] '------------------------------'
# [Line 250] 'Account No : 06971300000866 Nomination Registered :'
# [Line 251] 'No'
# [Line 252] 'A/C Name : M/S. KAMAL BRICKS INDUSTRY Nominee Name :'
# [Line 253] 'Address : 560 MOTA SINGH NAGAR'
# [Line 254] 'JALANDHAR'
# [Line 255] 'City : JALANDHAR (PPin Code : 144001'
# [Line 256] 'Tel No. : Sanction Limit :'
# [Line 257] '3000000'
# [Line 258] 'A/C Holder : KAMAL BRICKS INDUSTRY TOD Limit :'
# [Line 259] '0'
# [Line 260] 'Joint Holders: Interest Rate :'
# [Line 261] '13.1'
# [Line 262] 'Open Date : 31-05-2017'
# [Line 263] 'Statement of account for the period of 01-04-2022 to 25-06-2023'
# [Line 264] 'REPORT!MAILID#'
# [Line 265] 'NOTE:'
# [Line 266] '1) Maximum interest rate is displayed for account with multiple Sanction Limits'
# [Line 267] '2) Sanction Limit and Interest Rate is as on Calendar date'
# [Line 268] '3) For further clarification regarding Sanction Limit and Interest Rate please'
# [Line 269] 'contact home branch'
# [Line 270] 'Note:DICGC insures principal & interest of eligible depositors,upto a maximum'
# [Line 271] 'admissible amount of Rs 5 lakh'
# [Line 272] 'subject to changes from time to time**T&C of DICGC shall apply.'
# [Line 273] '****END OF STATEMENT****'
